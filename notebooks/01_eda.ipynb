# %% [markdown]
# # NHANES EDA
#
# This notebook is a stub. Suggested steps:
# - Load cached NHANES via `src.data_loader`
# - Inspect missingness + distributions
# - Check target prevalence by subgroup
